# %%
import import_ipynb
import authenticate_developer

# %% [markdown]
# Add your authentication credentials from your twitter developer account

# %% [markdown]
# Client credentials:
#
#     App Key === API Key === Consumer API Key === Consumer Key === Customer Key === oauth_consumer_key
#     App Key Secret === API Secret Key === Consumer Secret === Consumer Key === Customer Key === oauth_consumer_secret
#     Callback URL === oauth_callback
#
#
# Token credentials:
#
#     Access token === Token === resulting oauth_token
#     Access token secret === Token Secret === resulting oauth_token_secret

# %%
ACCESS_TOKEN = 'YOUR_ACCESS_TOKEN'
ACCESS_SECRET = 'YOUR_ACCESS_SECRET'
CONSUMER_KEY = 'YOUR_CONSUMER_KEY'
CONSUMER_SECRET = 'YOUR_CONSUMER_SECRET'

# %% [markdown]
# Set up api instance

# %%
authenticate = authenticate_developer.Authenticate(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %% [markdown]
# Connect to twitter

# %%
api = authenticate.connect_to_twitter_OAuth()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fbb620c85b0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/account/verify_credentials.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fbb620c85b0>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/account/verify_credentials.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fbb620c85b0>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-35-92860288fa20> in <module>
#       1 authenticate = authenticate_developer.Authenticate(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
# ----> 2 api = authenticate.connect_to_twitter_OAuth()
#       3 # print(api)
#
# ~/Desktop/twitter-plugin/src/authenticate_developer.ipynb in connect_to_twitter_OAuth(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/api.py in verify_credentials(self, **kwargs)
#     670             kwargs['include_email'] = str(kwargs['include_email']).lower()
#     671         try:
# --> 672             return bind_api(
#     673                 api=self,
#     674                 path='/account/verify_credentials.json',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/six.py in reraise(tp, value, tb)
#     700                 value = tp()
#     701             if value.__traceback__ is not tb:
# --> 702                 raise value.with_traceback(tb)
#     703             raise value
#     704         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     182                 # Execute request
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#     186                                                 data=self.post_data,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/account/verify_credentials.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fbb620c85b0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %% [markdown]
# Create importer instance. Enter a user handle from which you want to import data e.g realdonaldtrump

# %%
twitter_importer = TwitterImporter('user_handle')

# %% [markdown]
# Get followers of a given user

# %%
followers = twitter_importer.import_followers()

# %%
# Print out items
# for item in followers:
#     print (item)

# %% [markdown]
# Get followings of a given user

# %%
followings = twitter_importer.import_followings()

# %%
# # Print out items
# for item in followings:
#     print (item)
# Out:
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 1268909056904716288, 'id_str': '1268909056904716288', 'name': 'Memri', 'screen_name': 'YourMemri', 'location': '', 'description': 'Open source project that enables you to import and manage your data from a single encrypted environment. A tool to truly control your data.', 'url': 'https://t.co/6zbPMpB5YY', 'entities': {'url': {'urls': [{'url': 'https://t.co/6zbPMpB5YY', 'expanded_url': 'https://memri.cloud/', 'display_url': 'memri.cloud', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 261, 'friends_count': 278, 'listed_count': 1, 'created_at': 'Fri Jun 05 14:15:15 +0000 2020', 'favourites_count': 993, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 225, 'lang': None, 'status': {'created_at': 'Thu Apr 01 14:21:14 +0000 2021', 'id': 1377627116515295241, 'id_str': '1377627116515295241', 'text': 'RT @Casper_Network: Today is a day of great significance, not just for the Casper Association and CasperLabs team but for our community, an…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Casper_Network', 'name': 'Casper', 'id': 1061731562637553664, 'id_str': '1061731562637553664', 'indices': [3, 18]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Mar 31 05:57:37 +0000 2021', 'id': 1377137989722107905, 'id_str': '1377137989722107905', 'text': 'Today is a day of great significance, not just for the Casper Association and CasperLabs team but for our community… https://t.co/EUcmpP4pMF', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/EUcmpP4pMF', 'expanded_url': 'https://twitter.com/i/web/status/1377137989722107905', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 309, 'favorite_count': 834, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 309, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1278708358661287937/jyh5a6iL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278708358661287937/jyh5a6iL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1268909056904716288/1594291951', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1268909056904716288, id_str='1268909056904716288', name='Memri', screen_name='YourMemri', location='', description='Open source project that enables you to import and manage your data fr ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 1127292075840401408, 'id_str': '1127292075840401408', 'name': 'Amber Horvath', 'screen_name': 'AmberHorvath1', 'location': 'United States', 'description': 'PhD student at Carnegie Mellon University studying methods for improving usability and learnability of APIs. I like biking, coffee shops, and arguing on reddit', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54, 'friends_count': 24, 'listed_count': 0, 'created_at': 'Sat May 11 19:19:09 +0000 2019', 'favourites_count': 3, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4, 'lang': None, 'status': {'created_at': 'Tue Mar 23 14:05:17 +0000 2021', 'id': 1374361613311094786, 'id_str': '1374361613311094786', 'text': 'Do you hate bad API documentation? @bradamyers and I are trying to fix it! We need developers who use Google Chrome… https://t.co/z6Sp6B0fwg', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'bradamyers', 'name': 'Brad Myers', 'id': 50781152, 'id_str': '50781152', 'indices': [35, 46]}], 'urls': [{'url': 'https://t.co/z6Sp6B0fwg', 'expanded_url': 'https://twitter.com/i/web/status/1374361613311094786', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 16, 'favorite_count': 30, 'favorited': True, 'retweeted': True, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1127292714016395264/kHA2lNk9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1127292714016395264/kHA2lNk9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1127292075840401408/1557602698', 'profile_link_color': 'E81C4F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1127292075840401408, id_str='1127292075840401408', name='Amber Horvath', screen_name='AmberHorvath1', location='United States', description='PhD student at Carnegie Mellon University studying methods for improving usability and learnability of APIs. I like biking, coffee shops, and arguing on reddit', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=54, friends_count=24, listed_count=0, created_at=datetime.datetime(2019, 5, 11, 19, 19, 9), favourites_count=3, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=4, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Tue Mar 23 14:05:17 +0000 2021', 'id': 1374361613311094786, 'id_str': '1374361613311094786', 'text': 'Do you hate bad API documentation? @bradamyers and I are trying to fix it! We need developers who use Google Chrome… https://t.co/z6Sp6B0fwg', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'bradamyers', 'name': 'Brad Myers', 'id': 50781152, 'id_str': '50781152', 'indices' ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 2375613192, 'id_str': '2375613192', 'name': 'Deeper Fellowship Church', 'screen_name': 'Deeper_Church', 'location': 'Orlando', 'description': 'We exist to cultivate a deeper fellowship with God and one another | Lead Pastor @WilliamMcDowell | Sunday online @ 10:30 on Youtube & Facebook', 'url': 'https://t.co/DwBFkIdzXL', 'entities': {'url': {'urls': [{'url': 'https://t.co/DwBFkIdzXL', 'expanded_url': 'http://www.deeperfellowshipchurch.org', 'display_url': 'deeperfellowshipchurch.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2581, 'friends_count': 25, 'listed_count': 9, 'created_at': 'Thu Mar 06 16:38:21 +0000 2014', 'favourites_count': 560, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 7287, 'lang': None, 'status': {'created_at': 'Sun Apr 18 17:43:35 +0000 2021', 'id': 1383838633816313867, 'id_str': '1383838633816313867', 'text': 'We teach the fellowship of Christ sufferings yet refuse to be united in the sufferings of other believers. @WilliamMcDowell', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'WilliamMcDowell', 'name': 'William McDowell', 'id': 236917131, 'id_str': '236917131', 'indices': [107, 123]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1383837008267677706, 'in_reply_to_status_id_str': '1383837008267677706', 'in_reply_to_user_id': 2375613192, 'in_reply_to_user_id_str': '2375613192', 'in_reply_to_screen_name': 'Deeper_Church', 'geo': None, 'coordinates': None, 'place': {'id': 'dc96a032c98a1ea9', 'url': 'https://api.twitter.com/1.1/geo/id/dc96a032c98a1ea9.json', 'place_type': 'city', 'name': 'Winter Garden', 'full_name': 'Winter Garden, FL', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-81.625844, 28.49675], [-81.554843, 28.49675], [-81.554843, 28.595488], [-81.625844, 28.595488]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1132529093587722240/lxPDRg67_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1132529093587722240/lxPDRg67_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2375613192/1558850920', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2375613192, id_str='2375613192', name='Deeper Fellowship Church', screen_name='Deeper_Church', location='Orlando', description='We exist to cultivate a deeper fellowship with God and one another | Lead Pastor @WilliamMcDowell | Sunday online @ 10:30 on Youtube & Facebook', url='https://t.co/DwBFkIdzXL', entities={'url': {'urls': [{'url': 'https://t.co/DwBFkIdzXL', 'expanded_url': 'http://www.deeperfellowshipchurch.org', 'display_url': 'deeperfellowshipchurch.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=2581, friends_count=25, listed_count=9, created_at=datetime.datetime(2014, 3 ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 1298004076295118848, 'id_str': '1298004076295118848', 'name': 'Diana', 'screen_name': 'diana_ashktorab', 'location': '', 'description': "#CodeNewbie(8 yo).\nLOVE programming.\nJoin me & let's have fun learning #HTML & #CSS \nmentored by @CodeValentina & @siminmaleki\ntweets supervised by mom", 'url': 'https://t.co/dz2m2DFK70', 'entities': {'url': {'urls': [{'url': 'https://t.co/dz2m2DFK70', 'expanded_url': 'http://codepen.io/superpowerkid', 'display_url': 'codepen.io/superpowerkid', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 6379, 'friends_count': 426, 'listed_count': 27, 'created_at': 'Mon Aug 24 21:07:50 +0000 2020', 'favourites_count': 1130, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 480, 'lang': None, 'status': {'created_at': 'Fri Apr 23 14:05:44 +0000 2021', 'id': 1385595749736587267, 'id_str': '1385595749736587267', 'text': "💫CSS tip \n👨\u200d👧\u200d👦nth-child()\nIt's used to call 1 of the elements that have common IDs 🤔just like traffic light\n\nAlso… https://t.co/Tn9xZds9BA", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Tn9xZds9BA', 'expanded_url': 'https://twitter.com/i/web/status/1385595749736587267', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 6, 'favorite_count': 44, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1320094925690646528/NKLDV8hd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1320094925690646528/NKLDV8hd_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1298004076295118848/1600691343', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1298004076295118848, id_str='1298004076295118848', name='Diana', screen_name='diana_ashktorab', location='', description="#CodeNewbie(8 yo).\nLOVE programming.\nJoin me & let's have fun learning #HTML & #CSS \nmentored by @CodeValentina & @siminmaleki\ntweets supervised by mom", url='https://t.co/dz2m2DFK70', entities={'url': {'urls': [{'url': 'https://t.co/dz2m2DFK70', 'expanded_url': 'http://codepen.io/superpowerkid', 'display_url': 'codepen.io/superpowerkid', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=6379, friends_count=426, listed_count=27, created_at=datetime.datetime(2020, 8, 24, 21, 7, 50), favourites_count=1130, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=480, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Fri Apr 23 14:05:44 +0000 2021', 'id': 1385595749736587267, 'id_str': '1385595749736587267', 'text': "💫CSS tip \n👨\u200d👧\u200d👦nth-child()\nIt's used to call 1 of the elements that have common IDs 🤔just like traffic light\n\nAlso… htt ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 167292689, 'id_str': '167292689', 'name': 'Ankur💻🎧💪', 'screen_name': 'TheAnkurTyagi', 'location': 'India', 'description': 'Software Engineer | Mentor\n\nTalk to me 1-1 👉 https://t.co/eGqmCqf16B\n\nNewsletter : https://t.co/ljIbuybZzV | Prime Guide: https://t.co/WuD5u3wDfd', 'url': 'https://t.co/p2JWAjRvZK', 'entities': {'url': {'urls': [{'url': 'https://t.co/p2JWAjRvZK', 'expanded_url': 'https://theankurtyagi.com/', 'display_url': 'theankurtyagi.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/eGqmCqf16B', 'expanded_url': 'https://hiretheauthor.com/theankurtyagi', 'display_url': 'hiretheauthor.com/theankurtyagi', 'indices': [45, 68]}, {'url': 'https://t.co/ljIbuybZzV', 'expanded_url': 'http://codelifefitness.com/2-1-1/', 'display_url': 'codelifefitness.com/2-1-1/', 'indices': [83, 106]}, {'url': 'https://t.co/WuD5u3wDfd', 'expanded_url': 'http://gum.co/nextgendev', 'display_url': 'gum.co/nextgendev', 'indices': [122, 145]}]}}, 'protected': False, 'followers_count': 11862, 'friends_count': 422, 'listed_count': 215, 'created_at': 'Fri Jul 16 06:06:25 +0000 2010', 'favourites_count': 23050, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 14191, 'lang': None, 'status': {'created_at': 'Sat Apr 24 08:52:27 +0000 2021', 'id': 1385879298658115585, 'id_str': '1385879298658115585', 'text': "RT @chris_herd: People don’t care about ‘the future of work’\n\nWhat they care about is ‘the future of living’\n\nIf we don't use remote work a…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'chris_herd', 'name': 'Chris Herd', 'id': 67640827, 'id_str': '67640827', 'indices': [3, 14]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Apr 17 07:54:14 +0000 2021', 'id': 1383327931204657158, 'id_str': '1383327931204657158', 'text': "People don’t care about ‘the future of work’\n\nWhat they care about is ‘the future of living’\n\nIf we don't use remot… https://t.co/jzZMkfsYa2", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/jzZMkfsYa2', 'expanded_url': 'https://twitter.com/i/web/status/1383327931204657158', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 42, 'favorite_count': 282, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 42, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1265715524224184321/JZYqy6W4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1265715524224184321/JZYqy6W4_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/167292689/1616581545', 'profile_link_color': '3B94D9', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_tex ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 78722536, 'id_str': '78722536', 'name': 'Trinity Anderson', 'screen_name': 'MizTrinity', 'location': 'Orlando!', 'description': '“Live a life that’s worthy of your calling!” - Eph 4:1', 'url': 'https://t.co/scCotBD3Ka', 'entities': {'url': {'urls': [{'url': 'https://t.co/scCotBD3Ka', 'expanded_url': 'https://trinityanderson.lnk.to/GrownUpChristmasListTW', 'display_url': 'trinityanderson.lnk.to/GrownUpChristm…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2304, 'friends_count': 1081, 'listed_count': 9, 'created_at': 'Wed Sep 30 22:13:15 +0000 2009', 'favourites_count': 3716, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12170, 'lang': None, 'status': {'created_at': 'Fri Apr 23 16:27:12 +0000 2021', 'id': 1385631349793505280, 'id_str': '1385631349793505280', 'text': 'Happy Friday! I love you ♥️', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 9, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1256901717863604226/ILFCM38v_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256901717863604226/ILFCM38v_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/78722536/1605240210', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=78722536, id_str='78722536', name='Trinity Anderson', screen_name='MizTrinity', location='Orlando!', description='“Live a life that’s worthy of your calling!” - Eph 4:1', url='https://t.co/scCotBD3Ka', entities={'url': {'urls': [{'url': 'https://t.co/scCotBD3Ka', 'expanded_url': 'https://trinityanderson.lnk.to/GrownUpChristmasListTW', 'display_url': 'trinityanderson.lnk.to/GrownUpChristm…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=2304, friends_count=1081, listed_count=9, created_at=datetime.datetime(2009, 9, 30, 22, 13, 15), favourites_count=3716, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=12170, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Fri Apr 23 16:27:12 +0000 2021', 'id': 1385631349793505280, 'id_str': '1385631349793505280', 'text': 'Happy Friday! I love you ♥️', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_ ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 3241119489, 'id_str': '3241119489', 'name': 'I*Musinguzi', 'screen_name': 'ArthurAtwooki', 'location': 'Kampala, Uganda', 'description': 'Esquire.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 65, 'friends_count': 147, 'listed_count': 0, 'created_at': 'Thu May 07 22:37:53 +0000 2015', 'favourites_count': 647, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 166, 'lang': None, 'status': {'created_at': 'Sun Jan 24 09:23:11 +0000 2021', 'id': 1353272123662491649, 'id_str': '1353272123662491649', 'text': '@Jude_Mugabi 😂😂😂😂', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Jude_Mugabi', 'name': 'The Usual Suspect 🎩', 'id': 712676897, 'id_str': '712676897', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1353233731935322112, 'in_reply_to_status_id_str': '1353233731935322112', 'in_reply_to_user_id': 712676897, 'in_reply_to_user_id_str': '712676897', 'in_reply_to_screen_name': 'Jude_Mugabi', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1084777341275000832/oUVOlKie_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1084777341275000832/oUVOlKie_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3241119489/1588531368', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=3241119489, id_str='3241119489', name='I*Musinguzi', screen_name='ArthurAtwooki', location='Kampala, Uganda', description='Esquire.', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=65, friends_count=147, listed_count=0, created_at=datetime.datetime(2015, 5, 7, 22, 37, 53), favourites_count=647, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=166, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Sun Jan 24 09:23:11 +0000 2021', 'id': 1353272123662491649, 'id_str': '1353272123662491649', 'text': '@Jude_Mugabi 😂😂😂😂', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Jude_Mugabi', 'name': 'The Usual Suspect 🎩', 'id': 712676897, 'id_str': '712676897', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1353233731935322112, 'in_reply_to_status_id_str': '1353233731935322112', 'in_reply_to_user_id': 712676897, 'in_reply_to_user_id_str': '712676897', 'in_reply_to_screen_name': 'Jude_Mugabi', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2021, 1, 24, 9, 23, 11), id=1353272123662491649, id_str='1353272123662491649', text='@Jude_Mugabi 😂😂😂😂', truncated=False, entities={' ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 518773805, 'id_str': '518773805', 'name': 'humie', 'screen_name': 'HumuRachel', 'location': 'kampala', 'description': 'Tuli kuki naye?', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 211, 'friends_count': 566, 'listed_count': 0, 'created_at': 'Thu Mar 08 19:00:18 +0000 2012', 'favourites_count': 3459, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 331, 'lang': None, 'status': {'created_at': 'Mon Apr 12 12:28:02 +0000 2021', 'id': 1381584895642890245, 'id_str': '1381584895642890245', 'text': 'RT @LunarRoot: Researching inclusive design so my ecovillage community designs are accessible... https://t.co/SOsaB58PVK', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'LunarRoot', 'name': 'Kayla Love', 'id': 1260424257252864008, 'id_str': '1260424257252864008', 'indices': [3, 13]}], 'urls': [], 'media': [{'id': 1381233802178129924, 'id_str': '1381233802178129924', 'indices': [97, 120], 'media_url': 'http://pbs.twimg.com/media/Eysg0zKW8AQ_twR.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Eysg0zKW8AQ_twR.jpg', 'url': 'https://t.co/SOsaB58PVK', 'display_url': 'pic.twitter.com/SOsaB58PVK', 'expanded_url': 'https://twitter.com/LunarRoot/status/1381233806347231239/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 643, 'h': 643, 'resize': 'fit'}, 'small': {'w': 643, 'h': 643, 'resize': 'fit'}, 'large': {'w': 643, 'h': 643, 'resize': 'fit'}}, 'source_status_id': 1381233806347231239, 'source_status_id_str': '1381233806347231239', 'source_user_id': 1260424257252864008, 'source_user_id_str': '1260424257252864008'}]}, 'extended_entities': {'media': [{'id': 1381233802178129924, 'id_str': '1381233802178129924', 'indices': [97, 120], 'media_url': 'http://pbs.twimg.com/media/Eysg0zKW8AQ_twR.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Eysg0zKW8AQ_twR.jpg', 'url': 'https://t.co/SOsaB58PVK', 'display_url': 'pic.twitter.com/SOsaB58PVK', 'expanded_url': 'https://twitter.com/LunarRoot/status/1381233806347231239/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 643, 'h': 643, 'resize': 'fit'}, 'small': {'w': 643, 'h': 643, 'resize': 'fit'}, 'large': {'w': 643, 'h': 643, 'resize': 'fit'}}, 'source_status_id': 1381233806347231239, 'source_status_id_str': '1381233806347231239', 'source_user_id': 1260424257252864008, 'source_user_id_str': '1260424257252864008'}, {'id': 1381233802190725120, 'id_str': '1381233802190725120', 'indices': [97, 120], 'media_url': 'http://pbs.twimg.com/media/Eysg0zNXIAApar5.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Eysg0zNXIAApar5.jpg', 'url': 'https://t.co/SOsaB58PVK', 'display_url': 'pic.twitter.com/SOsaB58PVK', 'expanded_url': 'https://twitter.com/LunarRoot/status/1381233806347231239/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 750, 'h': 529, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 750, 'h': 529, 'resize': 'fit'}, 'small': {'w': 680, 'h': 480, 'resize': 'fit'}}, 'source_status_id': 1381233806347231239, 'source_status_id_str': '1381233806347231239', 'source_user_id': 1260424257252864008, 'source_user_id_str': '1260424257252864008'}, {'id': 1381233802190725121, 'id_str': '1381233802190725121', 'indices': [97, 120], 'media_url': 'http://pbs.twimg.com/media/Eysg0zNXIAE6Ys4.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Eysg0zNXIAE6Ys4.jpg', 'url': 'https://t.co/SOsaB58PVK', 'display_url': 'pic.twitter.com/SOsaB58PVK', 'expanded_url': 'https://twitter.com/LunarRoot/status/1381233806347231239/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 348, 'h': 408, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 348, 'h': 408, 'resize': 'fit'}, 'small': {'w': 348, 'h': 408, 'resize': 'fit'}}, 'source_status_id':  ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 265993103, 'id_str': '265993103', 'name': 'Rey van den Berg', 'screen_name': 'ReyTheDev', 'location': 'Cape Town, South Africa', 'description': 'Web Designer & Developer 🎨⌨️\nMindfulness Advocate. React + Rails. Writer.', 'url': 'https://t.co/DweG6T0hxy', 'entities': {'url': {'urls': [{'url': 'https://t.co/DweG6T0hxy', 'expanded_url': 'http://www.fromthemountain.co.za', 'display_url': 'fromthemountain.co.za', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 959, 'friends_count': 98, 'listed_count': 12, 'created_at': 'Mon Mar 14 13:26:20 +0000 2011', 'favourites_count': 1614, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1214, 'lang': None, 'status': {'created_at': 'Sat Apr 03 10:32:50 +0000 2021', 'id': 1378294412455776257, 'id_str': '1378294412455776257', 'text': '@telmo "Date? Aaaaah" for me.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'telmo', 'name': 'Telmo', 'id': 1134106996796510209, 'id_str': '1134106996796510209', 'indices': [0, 6]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1378267358767296512, 'in_reply_to_status_id_str': '1378267358767296512', 'in_reply_to_user_id': 1134106996796510209, 'in_reply_to_user_id_str': '1134106996796510209', 'in_reply_to_screen_name': 'telmo', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 6, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1231889041085300736/SnVlq8pD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1231889041085300736/SnVlq8pD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/265993103/1597170265', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': True, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=265993103, id_str='265993103', name='Rey van den Berg', screen_name='ReyTheDev', location='Cape Town, South Africa', description='Web Designer & Developer 🎨⌨️\nMindfulness Advocate. React + Rails. Writer.', url='https://t.co/DweG6T0hxy', entities={'url': {'urls': [{'url': 'https://t.co/DweG6T0hxy', 'expanded_url': 'http://www.fromthemountain.co.za', 'display_url': 'fromthemountain.co.za', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=959, friends_count=98, listed_count=12, created_at=datetime.datetime(2011, 3, 14, 13, 26, 20), favourites_count=1614, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=1214, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Sat Apr 03 10:32:50 +0000 2021', 'id': 1378294412455776257, 'id_str': '1378294412455776257', 'text': '@telmo "Date? Aaaaah" for me.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'telmo', 'name': 'Telmo', 'id': 1134106996796510209, 'id_str': '1134106996796510209', 'indices': [0, 6]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter fo ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 780010946, 'id_str': '780010946', 'name': 'Eva Muhanguzi', 'screen_name': 'evahguzi', 'location': 'Oakland, CA', 'description': 'Believer | Amateur photographer| Wife | Data-science', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 856, 'friends_count': 1213, 'listed_count': 20, 'created_at': 'Sat Aug 25 10:05:16 +0000 2012', 'favourites_count': 1722, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4495, 'lang': None, 'status': {'created_at': 'Wed Apr 21 19:25:41 +0000 2021', 'id': 1384951490243186690, 'id_str': '1384951490243186690', 'text': 'Thank you  @edwardleefilms for the video on Cable management..... https://t.co/l81wigPcqi', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'edwardleefilms', 'name': 'Edward Lee', 'id': 1006023828135219201, 'id_str': '1006023828135219201', 'indices': [11, 26]}], 'urls': [], 'media': [{'id': 1384951483788009474, 'id_str': '1384951483788009474', 'indices': [66, 89], 'media_url': 'http://pbs.twimg.com/media/EzhWCWZVoAIQdX8.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EzhWCWZVoAIQdX8.jpg', 'url': 'https://t.co/l81wigPcqi', 'display_url': 'pic.twitter.com/l81wigPcqi', 'expanded_url': 'https://twitter.com/evahguzi/status/1384951490243186690/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}, 'small': {'w': 680, 'h': 510, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1384951483788009474, 'id_str': '1384951483788009474', 'indices': [66, 89], 'media_url': 'http://pbs.twimg.com/media/EzhWCWZVoAIQdX8.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EzhWCWZVoAIQdX8.jpg', 'url': 'https://t.co/l81wigPcqi', 'display_url': 'pic.twitter.com/l81wigPcqi', 'expanded_url': 'https://twitter.com/evahguzi/status/1384951490243186690/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}, 'small': {'w': 680, 'h': 510, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}}}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '487991', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/876375977194029056/ezbs31-5_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/876375977194029056/ezbs31-5_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/780010946/1417441956', 'profile_link_color': '009999', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'E5507E', 'profile_text_color': '362720', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=780010946, id_str='780010946', name='Eva Muhanguzi', screen_name='evahguzi', location='Oakland, CA', description='Believer | Amateur photographer| W ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 1574564864, 'id_str': '1574564864', 'name': 'Bellé of the App', 'screen_name': 'atuhighray', 'location': 'No. 12 Grimmauld place  01965', 'description': "Quantity Surveyor.\nI'm probably pissed off!\nintroverted-leave me alone. high key Potterhead", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 15967, 'friends_count': 5489, 'listed_count': 9, 'created_at': 'Sun Jul 07 07:28:28 +0000 2013', 'favourites_count': 52391, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 71719, 'lang': None, 'status': {'created_at': 'Sat Apr 24 04:41:33 +0000 2021', 'id': 1385816156880216064, 'id_str': '1385816156880216064', 'text': '@AKyasiimire I have read books but that Alchemist  book by Paul Coelho was some shit. \nIt changes you.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AKyasiimire', 'name': 'Agnes Kyasiimire', 'id': 1093465255819337728, 'id_str': '1093465255819337728', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1385647138600783875, 'in_reply_to_status_id_str': '1385647138600783875', 'in_reply_to_user_id': 1093465255819337728, 'in_reply_to_user_id_str': '1093465255819337728', 'in_reply_to_screen_name': 'AKyasiimire', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1371128043046113287/pMB6KAp4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1371128043046113287/pMB6KAp4_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1574564864/1565205252', 'profile_link_color': 'FA743E', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1574564864, id_str='1574564864', name='Bellé of the App', screen_name='atuhighray', location='No. 12 Grimmauld place  01965', description="Quantity Surveyor.\nI'm probably pissed off!\nintroverted-leave me alone. high key Potterhead", url=None, entities={'description': {'urls': []}}, protected=False, followers_count=15967, friends_count=5489, listed_count=9, created_at=datetime.datetime(2013, 7, 7, 7, 28, 28), favourites_count=52391, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=71719, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Sat Apr 24 04:41:33 +0000 2021', 'id': 1385816156880216064, 'id_str': '1385816156880216064', 'text': '@AKyasiimire I have read books but that Alchemist  book by Paul Coelho was some shit. \nIt changes you.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AKyasiimire', 'name': 'Agnes Kyasiimire', 'id': 1093465255819337728, 'id_str': '1093465255819337728', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1385647138600783875, 'in_reply_to_status_id_str': '1385647138600783875', 'in_r ...
# ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 80605078, 'id_str': '80605078', 'name': 'Michael Niyitegeka', 'screen_name': 'niyimic', 'location': 'Uganda', 'description': 'Living my Purpose|Country Manager-Uganda; ICDL Africa| Certified Facilitator| Director @Refactory https://t.co/ifrNA01fRq', 'url': 'https://t.co/xBzjScKsw5', 'entities': {'url': {'urls': [{'url': 'https://t.co/xBzjScKsw5', 'expanded_url': 'http://www.icdlafrica.org', 'display_url': 'icdlafrica.org', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/ifrNA01fRq', 'expanded_url': 'http://www.refactory.ug', 'display_url': 'refactory.ug', 'indices': [98, 121]}]}}, 'protected': False, 'followers_count': 30859, 'friends_count': 769, 'listed_count': 167, 'created_at': 'Wed Oct 07 15:38:37 +0000 2009', 'favourites_count': 32271, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 56545, 'lang': None, 'status': {'created_at': 'Sat Apr 24 08:15:50 +0000 2021', 'id': 1385870080601477120, 'id_str': '1385870080601477120', 'text': '@kasyate Hehehe.....it  still looks good on you... ;-)', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kasyate', 'name': 'Simon Peter Kasyate', 'id': 1482913034, 'id_str': '1482913034', 'indices': [0, 8]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1385869144789340165, 'in_reply_to_status_id_str': '1385869144789340165', 'in_reply_to_user_id': 1482913034, 'in_reply_to_user_id_str': '1482913034', 'in_reply_to_screen_name': 'kasyate', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1019818347951677440/v3WBf8Kr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1019818347951677440/v3WBf8Kr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80605078/1354045372', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=80605078, id_str='80605078', name='Michael Niyitegeka', screen_name='niyimic', location='Uganda', description='Living my Purpose|Country Manager-Uganda; ICDL Africa| Certified Facilitator| Director @Refactory https://t.co/ifrNA01fRq', url='https://t.co/xBzjScKsw5', entities={'url': {'urls': [{'url': 'https://t.co/xBzjScKsw5', 'expanded_url': 'http://www.icdlafrica.org', 'display_url': 'icdlafrica.org', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/ifrNA01fRq', 'expanded_url': 'http://www.refactory.ug', 'display_url': 'refactory.ug', 'indices': [98, 121]}]}}, protected=False, followers_count=30859, friends_count=769, listed_count=167, created_at=datetime.datetime(2009, 10, 7, 15, 38, 37), favourites_count=32271, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=56545, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Sat Apr 24 08:15:50 +0000 2021', 'id': 1385870080601477120, 'id_str': '1385870080601477120', 'text': '@kasyate Hehehe.....it  still looks g ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 44671362, 'id_str': '44671362', 'name': 'BibleStudyTools', 'screen_name': 'biblestudytools', 'location': '', 'description': 'The largest free online Bible Study website for verse search, trivia and in-depth study. Now you can save your own notes or create a page for your small group!', 'url': 'http://t.co/dRt9Rk8BC3', 'entities': {'url': {'urls': [{'url': 'http://t.co/dRt9Rk8BC3', 'expanded_url': 'http://biblestudytools.com', 'display_url': 'biblestudytools.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 20365, 'friends_count': 3842, 'listed_count': 361, 'created_at': 'Thu Jun 04 17:43:29 +0000 2009', 'favourites_count': 97, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10875, 'lang': None, 'status': {'created_at': 'Sat Jan 02 00:01:03 +0000 2021', 'id': 1345158125872177154, 'id_str': '1345158125872177154', 'text': "10 New Year's Prayers to Begin 2021 with Faith and Hope\nhttps://t.co/bqAuSjMobF", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/bqAuSjMobF', 'expanded_url': 'https://buff.ly/3htvawU', 'display_url': 'buff.ly/3htvawU', 'indices': [56, 79]}]}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 8, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '681800', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/709349618920898560/9-wg_knh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/709349618920898560/9-wg_knh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44671362/1457957110', 'profile_link_color': '631900', 'profile_sidebar_border_color': '631900', 'profile_sidebar_fill_color': 'FFD45C', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=44671362, id_str='44671362', name='BibleStudyTools', screen_name='biblestudytools', location='', description='The largest free online Bible Study website for verse search, trivia and in-depth study. Now you can save your own notes or create a page for your small group!', url='http://t.co/dRt9Rk8BC3', entities={'url': {'urls': [{'url': 'http://t.co/dRt9Rk8BC3', 'expanded_url': 'http://biblestudytools.com', 'display_url': 'biblestudytools.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, protected=False, followers_count=20365, friends_count=3842, listed_count=361, created_at=datetime.datetime(2009, 6, 4, 17, 43, 29), favourites_count=97, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=10875, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Sat Jan 02 00:01:03 +0000 2021', 'id': 1345158125872177154, 'id_str': '1345158125872177154', 'text': "10 New Year's Prayers to Begin 2021 with Faith and Hope\nhttps://t.co/bqAuSjMobF", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/bqAuSjMobF', 'expan ...
# User(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'id': 3088638688, 'id_str': '3088638688', 'name': 'esther hilda', 'screen_name': 'lueshilda941', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 10, 'friends_count': 26, 'listed_count': 0, 'created_at': 'Thu Mar 12 11:24:01 +0000 2015', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'status': {'created_at': 'Thu Mar 12 16:33:09 +0000 2015', 'id': 576058357079011329, 'id_str': '576058357079011329', 'text': 'Mmmmmmmh strikes &amp; tests what a week!!!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1042032941721964544/AbIqWdkW_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1042032941721964544/AbIqWdkW_normal.jpg', 'profile_link_color': '9266CC', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=3088638688, id_str='3088638688', name='esther hilda', screen_name='lueshilda941', location='', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=10, friends_count=26, listed_count=0, created_at=datetime.datetime(2015, 3, 12, 11, 24, 1), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=1, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fe5f3298790>, _json={'created_at': 'Thu Mar 12 16:33:09 +0000 2015', 'id': 576058357079011329, 'id_str': '576058357079011329', 'text': 'Mmmmmmmh strikes &amp; tests what a week!!!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2015, 3, 12, 16, 33, 9), id=576058357079011329, id_str='576058357079011329', text='Mmmmmmmh strikes &amp; tests what a week!!!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, f ...

# %% [markdown]
# Get tweets for a given user timeline, user and friends tweets

# %%
# User and followings tweets
user_tweets = twitter_importer.import_user_tweets()

# %% [markdown]
# Extract tweets to data frame

# %%
def extract_tweet_attributes(tweet_object):
    # create empty list
    tweet_list =[]
#     loop through tweet objects
    for tweet in tweet_object:
        tweet_id = tweet.id # unique integer identifier for tweet
        full_text = tweet.full_text # utf-8 text of tweet
        favorite_count = tweet.favorite_count
        retweet_count = tweet.retweet_count
        created_at = tweet.created_at # utc time tweet created
        source = tweet.source # utility used to post tweet
        reply_to_status = tweet.in_reply_to_status_id # if reply int of orginal tweet id
        reply_to_user = tweet.in_reply_to_screen_name # if reply original tweetes screenname
        retweets = tweet.retweet_count # number of times this tweet retweeted
        favorites = tweet.favorite_count # number of time this tweet liked
        # append attributes to list
        tweet_list.append({'tweet_id':tweet_id, 
                          'full_text':full_text, 
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                          'created_at':created_at, 
                          'source':source, 
                          'reply_to_status':reply_to_status, 
                          'reply_to_user':reply_to_user,
                          'retweets':retweets,
                          'favorites':favorites})
    # create dataframe   
    df = pd.DataFrame(tweet_list, columns=['tweet_id',
                                           'full_text',
                                           'favorite_count',
                                           'retweet_count',
                                           'created_at',
                                           'source',
                                           'reply_to_status',
                                           'reply_to_user',
                                           'retweets',
                                           'favorites'])
    return df


user_retweets_file = extract_tweet_attributes(user_tweets)

# %%
print(user_retweets_file)
# Out:
# Empty DataFrame
# Columns: [tweet_id, full_text, favorite_count, retweet_count, created_at, source, reply_to_status, reply_to_user, retweets, favorites]
# Index: []

# %% [markdown]
# Get tweets for a given user
